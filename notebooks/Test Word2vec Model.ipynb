# %%
import gensim

# %%
model = gensim.models.Word2Vec.load('../pretrain_models/twitter_w2c_300')

# %%
model.wv.evaluate_word_analogies('../data/external/questions-words.txt')
# Out:
# (0.021798365122615803,
#  [{'section': 'capital-common-countries',
#    'correct': [('BERLIN', 'GERMANY', 'OTTAWA', 'CANADA'),
#     ('BERN', 'SWITZERLAND', 'OTTAWA', 'CANADA')],
#    'incorrect': [('BERLIN', 'GERMANY', 'BERN', 'SWITZERLAND'),
#     ('BERLIN', 'GERMANY', 'MOSCOW', 'RUSSIA'),
#     ('BERLIN', 'GERMANY', 'PARIS', 'FRANCE'),
#     ('BERN', 'SWITZERLAND', 'MOSCOW', 'RUSSIA'),
#     ('BERN', 'SWITZERLAND', 'PARIS', 'FRANCE'),
#     ('BERN', 'SWITZERLAND', 'BERLIN', 'GERMANY'),
#     ('MOSCOW', 'RUSSIA', 'OTTAWA', 'CANADA'),
#     ('MOSCOW', 'RUSSIA', 'PARIS', 'FRANCE'),
#     ('MOSCOW', 'RUSSIA', 'BERLIN', 'GERMANY'),
#     ('MOSCOW', 'RUSSIA', 'BERN', 'SWITZERLAND'),
#     ('OTTAWA', 'CANADA', 'PARIS', 'FRANCE'),
#     ('OTTAWA', 'CANADA', 'BERLIN', 'GERMANY'),
#     ('OTTAWA', 'CANADA', 'BERN', 'SWITZERLAND'),
#     ('OTTAWA', 'CANADA', 'MOSCOW', 'RUSSIA'),
#     ('PARIS', 'FRANCE', 'BERLIN', 'GERMANY'),
#     ('PARIS', 'FRANCE', 'BERN', 'SWITZERLAND'),
# ...

# %%
model.most_similar('hello')
# Out:
# /data/kits/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('drawn', 0.9967591762542725),
#  ('class', 0.9964998364448547),
#  ('enough', 0.9964540004730225),
#  ('entire', 0.9960248470306396),
#  ('true', 0.9955975413322449),
#  ('friday', 0.9953778386116028),
#  ('become', 0.995111346244812),
#  ('broke', 0.9951056241989136),
#  ('wednesday', 0.9950299263000488),
#  ('mouth', 0.9946738481521606)]
